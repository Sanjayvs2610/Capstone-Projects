# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# %%
df = pd.read_csv("DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ### Task 1- Number of rows and columns and first 50 title and genre

# %%
df.shape
# Out:
# (4803, 20)

# %% [markdown]
# ##### Here i have displayed the total number of rows and columns present in the data

# %%
Gen_title = df[["genres","title"]]
Gen_title[:50]
# Out:
#                                                genres  \
# 0   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1   [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6   [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8   [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 15  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# ...

# %% [markdown]
# ##### Here i loaded the data and displayed the first 50 rows from columns of genres and title

# %% [markdown]
# ### Task 2 - Identify the null values and perform null values treatment

# %%
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %% [markdown]
# ##### There are some null values present in the dataset

# %% [markdown]
# ##### Cleaning the null values from the columns
# - For categorical we have to replace it by using mode of the column
# - For numerical column we have to treat it with the mean or median of the columns

# %%
numeric_columns = []
categorical_columns = []

for column in df.columns:
    if pd.api.types.is_numeric_dtype(df[column]):
        numeric_columns.append(column)
    else:
        categorical_columns.append(column)

table = [numeric_columns, categorical_columns]
print(tabulate({"numerical":numeric_columns,
                "categorical": categorical_columns}, headers = ["numerical", "categorical"]))
# Out:
# numerical     categorical
# ------------  --------------------
# budget        genres
# id            homepage
# popularity    keywords
# revenue       original_language
# runtime       original_title
# vote_average  overview
# vote_count    production_companies
#               production_countries
#               release_date
#               spoken_languages
#               status
#               tagline
#               title

# %%
def info_of_cat(col):
    print(f"Unique values in {col} are :{df[col].unique()}")
    print(f"Mode of {col} is : {df[col].mode()[0]}")
    print(f"Number of missing values in {col} is : {df[col].isnull().sum()}")

# %% [markdown]
# #### Performing null values treatment for the Homepage column

# %%
info_of_cat("homepage")
# Out:
# Unique values in homepage are :['http://www.avatarmovie.com/'
#  'http://disney.go.com/disneypictures/pirates/'
#  'http://www.sonypictures.com/movies/spectre/' ...
#  'http://www.primermovie.com'
#  'http://www.hallmarkchannel.com/signedsealeddelivered'
#  'http://shanghaicalling.com/']
# Mode of homepage is : http://www.missionimpossible.com/
# Number of missing values in homepage is : 3091

# %%
df["homepage"].fillna(" http://www.missionimpossible.com/",inplace=True)

# %% [markdown]
# #### Overview column

# %%
info_of_cat("overview")
# Out:
# Unique values in overview are :['In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'
#  'Captain Barbossa, long believed to be dead, has come back to life and is headed to the edge of the Earth with Will Turner and Elizabeth Swann. But nothing is quite as it seems.'
#  'A cryptic message from Bond’s past sends him on a trail to uncover a sinister organization. While M battles political forces to keep the secret service alive, Bond peels back the layers of deceit to reveal the terrible truth behind SPECTRE.'
#  ...
# ...

# %%
df["overview"].fillna("'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission,but becomes torn between following orders and protecting an alien civilization.'",inplace=True)

# %% [markdown]
# #### Release date column

# %%
info_of_cat("release_date")
# Out:
# Unique values in release_date are :['10-12-2009' '19-05-2007' '26-10-2015' ... '26-12-2011' '13-10-2013'
#  '03-05-2012']
# Mode of release_date is : 01-01-2006
# Number of missing values in release_date is : 1

# %%
df["release_date"].fillna("01-01-2006",inplace=True)

# %% [markdown]
# #### Tagline column

# %%
info_of_cat("tagline")
# Out:
# Unique values in tagline are :['Enter the World of Pandora.'
#  'At the end of the world, the adventure begins.' 'A Plan No One Escapes'
#  ...
#  "He didn't come looking for trouble, but trouble came looking for him."
#  "A newlywed couple's honeymoon is upended by the arrivals of their respective sisters."
#  'A New Yorker in Shanghai']
# Mode of tagline is : Based on a true story.
# Number of missing values in tagline is : 844

# %%
df["tagline"].fillna("Based on a true story",inplace=True)

# %% [markdown]
# #### Performing null tretament for the numerical columns

# %%
a = df["runtime"].mean()
a
# Out:
# 106.87585919600083

# %%
df["runtime"].fillna(a,inplace=True)

# %%
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# ##### All the null values presentin the data has been replaced , Now there is 0 null values in the dataset

# %% [markdown]
# ### Task 3 - Movie category budget greater than 220000

# %%
df1 = df[df["budget"]>220000]
df1
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4680     450000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4682   13000000                     [{"id": 27, "name": "Horror"}]
# 4720    8500000                      [{"id": 18, "name": "Drama"}]
# 4758    4000000  [{"id": 53, "name": "Thriller"}, {"id": 878, "...
# 4770     500000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# ...

# %%
df1[["budget","genres"]].sort_values(by="budget",ascending=False)
# Out:
#          budget                                             genres
# 17    380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4654     250000  [{"id": 28, "name": "Action"}, {"id": 14, "nam...
# 4661     245000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4664     230000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 4666     225000  [{"id": 10769, "name": "Foreign"}, {"id": 99, ...
# 4572     225000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
#
# [3684 rows x 2 columns]

# %% [markdown]
# ##### These are the movie categoeies whose budget is greater than $220,000 and i have arranged the data into descending order by budget of the film

# %% [markdown]
# ### Task 4 - Movie category where revenue is greater than 961,000,000

# %%
df2 = df[df["revenue"]>961000000]
df2
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3    250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 12   200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 17   380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 29   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 32   200000000  [{"id": 10751, "name": "Family"}, {"id": 14, "...
# 36   210000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# ...

# %%
df2[["revenue","genres"]].sort_values(by="revenue",ascending=False)
# Out:
#         revenue                                             genres
# 0    2787965087  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25   1845034188  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16   1519557910  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28   1513528810  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44   1506249360                     [{"id": 28, "name": "Action"}]
# 7    1405403694  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 124  1274219009  [{"id": 16, "name": "Animation"}, {"id": 12, "...
# 31   1215439994  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 546  1156730962  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 26   1153304495  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 52   1123746996  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 329  1118888979  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 29   1108561013  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %% [markdown]
# ##### These are the movies budget and genres , which has the revenue greater than $961,000,000

# %% [markdown]
# ### Task 5 - Remove the rows which has value 0 in the column of revenue and budget

# %%
df3 = df[(df["budget"]==0) | (df["revenue"]==0)]
df3
# Out:
#          budget                                             genres  \
# 83     27000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 135   150000000  [{"id": 18, "name": "Drama"}, {"id": 27, "name...
# 265           0  [{"id": 35, "name": "Comedy"}, {"id": 14, "nam...
# 309    84000000  [{"id": 14, "name": "Fantasy"}, {"id": 35, "na...
# 321           0                     [{"id": 35, "name": "Comedy"}]
# ...         ...                                                ...
# 4797          0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 83                    http://www.missionimpossible.com/   79698
# ...

# %%
df.drop(df3.index,inplace=True)

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ##### Here i droped the rows,which has 0 in revenue and budget columns . Now in df we can see that no 0 will be present in the budget and revenue columns

# %% [markdown]
# ### Task 6 - Top 10 movies with high revenue and least budget

# %%
df4 = df[["revenue","title"]].sort_values(by="revenue",ascending=False)
b = df4[:10][::-1]
b
# Out:
#         revenue                       title
# 26   1153304495  Captain America: Civil War
# 546  1156730962                     Minions
# 31   1215439994                  Iron Man 3
# 124  1274219009                      Frozen
# 7    1405403694     Avengers: Age of Ultron
# 44   1506249360                   Furious 7
# 28   1513528810              Jurassic World
# 16   1519557910                The Avengers
# 25   1845034188                     Titanic
# 0    2787965087                      Avatar

# %%
plt.figure(figsize=(16,9))
plt.barh(b["title"],b["revenue"])
plt.title("Top 10 Movies based on revenue")
plt.show()

# %% [markdown]
# ##### Top 10 movies based on highest revenue generated and i have displayed the output by Horizontal bar graph

# %%
df5 = df[["budget","title"]].sort_values(by="budget",ascending=True)
s = df5[:10][::-1]
s
# Out:
#       budget               title
# 1771      28      The 51st State
# 1912      25      Angela's Ashes
# 2933      11            F.I.S.T.
# 3137      10           Nurse 3-D
# 3131      10   Of Horses and Men
# 4608       8        The Prophecy
# 3419       7        Bran Nue Dae
# 3372       7        Split Second
# 3611       4  A Farewell to Arms
# 4238       1        Modern Times

# %%
plt.figure(figsize=(16,9))
plt.barh(s["title"],s["budget"])
plt.title("Top 10 least budget Movies")
plt.show()

# %% [markdown]
# ##### Top 10 movies with least budget , Modern times is least among all others .

# %% [markdown]
# ### Task 7 - Correlation between popularities and movie budget

# %%
df5 = df[["budget","popularity"]]
df5
# Out:
#          budget  popularity
# 0     237000000  150.437577
# 1     300000000  139.082615
# 2     245000000  107.376788
# 3     250000000  112.312950
# 4     260000000   43.926995
# ...         ...         ...
# 4773      27000   19.748658
# 4788      12000    4.553644
# 4792      20000    0.212443
# 4796       7000   23.307949
# 4798     220000   14.269792
#
# [3229 rows x 2 columns]

# %%
df5.corr()
# Out:
#              budget  popularity
# budget      1.00000     0.43199
# popularity  0.43199     1.00000

# %%
plt.scatter(df5["budget"],df5["popularity"])
plt.show()

# %% [markdown]
# ##### The budget and popularit has the low correlation , correlated percent is 43.199%

# %% [markdown]
# ### Task 8 - Identify production companies and number of time they appeared

# %%
df6 = pd.DataFrame(df["production_companies"].value_counts())
df6
# Out:
#                                                     production_companies
# [{"name": "Paramount Pictures", "id": 4}]                             48
# []                                                                    41
# [{"name": "Universal Pictures", "id": 33}]                            35
# [{"name": "New Line Cinema", "id": 12}]                               29
# [{"name": "Columbia Pictures", "id": 5}]                              28
# ...                                                                  ...
# [{"name": "Universal Pictures", "id": 33}, {"na...                     1
# [{"name": "Columbia Pictures", "id": 5}, {"name...                     1
# [{"name": "The Montecito Picture Company", "id"...                     1
# [{"name": "Camelot Productions", "id": 523}, {"...                     1
# [{"name": "Daiei Studios", "id": 881}]                                 1
#
# [2633 rows x 1 columns]

# %% [markdown]
# ##### Here i displayed the production companies and numberof tiems they appeared in the dataset

# %% [markdown]
# ### Task 9 - Display the top 25 production companies based on number movies they produced

# %%
df7 = df6.sort_values(by ="production_companies",ascending=False)[:25]
df7
# Out:
#                                                     production_companies
# [{"name": "Paramount Pictures", "id": 4}]                             48
# []                                                                    41
# [{"name": "Universal Pictures", "id": 33}]                            35
# [{"name": "New Line Cinema", "id": 12}]                               29
# [{"name": "Columbia Pictures", "id": 5}]                              28
# [{"name": "Twentieth Century Fox Film Corporati...                    25
# [{"name": "Warner Bros.", "id": 6194}]                                24
# [{"name": "Metro-Goldwyn-Mayer (MGM)", "id": 84...                    24
# [{"name": "Walt Disney Pictures", "id": 2}]                           18
# [{"name": "Touchstone Pictures", "id": 9195}]                         15
# [{"name": "Columbia Pictures Corporation", "id"...                    13
# [{"name": "Dimension Films", "id": 7405}]                             13
# ...

# %%
plt.figure(figsize=(10,15))
df7.plot(kind="bar")
plt.title("NUmber of movies by production companies")
plt.show()

# %% [markdown]
# ##### Paramount pictures has produce the highest number of movies

# %% [markdown]
# ### Task 10 - Filter top 500 movies and perform central tendancy

# %%
df8 = df.sort_values(by="revenue",ascending=False)[0:500]
df8
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44    190000000                     [{"id": 28, "name": "Action"}]
# ...         ...                                                ...
# 397    85000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 1744   30000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 698    70000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 717    60000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 714    65000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
#
#                                 homepage      id  \
# 0            http://www.avatarmovie.com/   19995
# 25           http://www.titanicmovie.com     597
# ...

# %% [markdown]
# #### budget column

# %%
a = df8["budget"].mean()
a
# Out:
# 103193736.0

# %%
b = df8["budget"].median()
b
# Out:
# 95000000.0

# %%
c = df8["budget"].mode()
c
# Out:
# 0    150000000
# Name: budget, dtype: int64

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x = df["budget"])
plt.show()

# %% [markdown]
# ##### central tendancy and boxplot  for the budget column

# %% [markdown]
# #### revenue column

# %%
w = df8["revenue"].mean()
w
# Out:
# 458577595.062

# %%
d = df8["revenue"].median()
d
# Out:
# 363001569.5

# %%
e = df8["revenue"].mode()
e
# Out:
# 0       217764291
# 1       218340595
# 2       218613188
# 3       219076518
# 4       219103655
#           ...
# 495    1506249360
# 496    1513528810
# 497    1519557910
# 498    1845034188
# 499    2787965087
# Name: revenue, Length: 500, dtype: int64

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x = df["revenue"])
plt.show()

# %% [markdown]
# ##### Central tendancy and boxplot for the revenue column

# %% [markdown]
# #### runtime column

# %%
x = df8["runtime"].mean()
x
# Out:
# 118.72

# %%
y = df8["runtime"].median()
y
# Out:
# 116.0

# %%
z = df8["runtime"].mode()
z
# Out:
# 0    115.0
# Name: runtime, dtype: float64

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x = df["runtime"])
plt.show()

# %% [markdown]
# ##### Central tendency and boxplot for runtime column

# %% [markdown]
# ### Task 11 - Name of the movies that run higher than the average runtime

# %%
df8
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44    190000000                     [{"id": 28, "name": "Action"}]
# ...         ...                                                ...
# 397    85000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 1744   30000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 698    70000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 717    60000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 714    65000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
#
#                                 homepage      id  \
# 0            http://www.avatarmovie.com/   19995
# 25           http://www.titanicmovie.com     597
# ...

# %%
df9 = df8[(df8["runtime"]>118.72)]

# %%
df9[["title","runtime"]].sort_values(by="runtime",ascending=False)
# Out:
#                                               title  runtime
# 3813                             Gone with the Wind    238.0
# 329   The Lord of the Rings: The Return of the King    201.0
# 1818                               Schindler's List    195.0
# 25                                          Titanic    194.0
# 690                                  The Green Mile    189.0
# ...                                             ...      ...
# 2668                                   Pretty Woman    119.0
# 245                             Tomorrow Never Dies    119.0
# 2667                               Fatal Attraction    119.0
# 249                                       Insurgent    119.0
# 1987                           Howl's Moving Castle    119.0
#
# [234 rows x 2 columns]

# %% [markdown]
# ##### These are the movies , which has runtime higher than the average runtime of the movies .
